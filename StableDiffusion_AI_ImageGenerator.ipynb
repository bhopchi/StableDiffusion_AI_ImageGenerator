# %% [markdown]
# <a href="https://colab.research.google.com/github/bhopchi/StableDiffusion_AI_ImageGenerator/blob/main/StableDiffusion_AI_ImageGenerator.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu118
# Out:
# Looking in indexes: https://download.pytorch.org/whl/cu118
# ...

# %% [markdown]
# # Import Libraries

# %%
from diffusers import StableDiffusionPipeline
import torch
from diffusers import StableDiffusionPipeline
from PIL import Image
import torch
from diffusers import StableDiffusionPipeline, DPMSolverMultistepScheduler

# %% [markdown]
# # Load the Stable Diffusion Model

# %%
# Load the pre-trained Stable Diffusion model from Hugging Face
model_id = "CompVis/stable-diffusion-v1-4"
device = "cuda" if torch.cuda.is_available() else "cpu"
# Load the pre-trained Stable Diffusion model from Hugging Face
model_id = "CompVis/stable-diffusion-v1-4"
device = "cuda" if torch.cuda.is_available() else "cpu"

# Initialize the pipeline
pipe = StableDiffusionPipeline.from_pretrained(model_id)
pipe = pipe.to(device)
# Out:
# model_index.json:   0%|          | 0.00/541 [00:00<?, ?B/s]
# Fetching 16 files:   0%|          | 0/16 [00:00<?, ?it/s]
# model.safetensors:   0%|          | 0.00/492M [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.22G [00:00<?, ?B/s]
# safety_checker/config.json:   0%|          | 0.00/4.56k [00:00<?, ?B/s]
# (…)ature_extractor/preprocessor_config.json:   0%|          | 0.00/342 [00:00<?, ?B/s]
# text_encoder/config.json:   0%|          | 0.00/592 [00:00<?, ?B/s]
# (…)kpoints/scheduler_config-checkpoint.json:   0%|          | 0.00/209 [00:00<?, ?B/s]
# tokenizer/merges.txt:   0%|          | 0.00/525k [00:00<?, ?B/s]
# scheduler/scheduler_config.json:   0%|          | 0.00/313 [00:00<?, ?B/s]
# tokenizer/special_tokens_map.json:   0%|          | 0.00/472 [00:00<?, ?B/s]
# tokenizer/tokenizer_config.json:   0%|          | 0.00/806 [00:00<?, ?B/s]
# diffusion_pytorch_model.safetensors:   0%|          | 0.00/3.44G [00:00<?, ?B/s]
# ...

# %% [markdown]
# # Generate Image from Textkeyboard_

# %%
def generate_image(prompt,image_size=(512,512)):
    # Generate an image from the text prompt
    with torch.autocast(device):
        # The following line was not indented correctly, leading to the error.
        # It should be indented to be part of the 'with' block.
        image = pipe(prompt)["images"][0]
    # Get the generated image
    return image

# %% [markdown]
# # Save or Display the Generated Image

# %%
def save_image(image, filename="generated_image.png"):
  # Save the image to disk
  image.save(filename)
  print(f"Image saved as {filename}")

def show_image(image):
  # Display the image
  display(image)  # Use display for showing images in Colab

# %% [markdown]
# # Main Function to Run the Project

# %%
def main():
  # Get text prompt from user
  prompt = input("Enter your text prompt: ")
  # Generate image based on prompt
  generated_image = generate_image(prompt)
  # Save and show the image
  show_image(generated_image)
  save_image(generated_image)

if __name__ == "__main__":
  main()
# Out:
# Enter your text prompt: lion
#   0%|          | 0/50 [00:00<?, ?it/s]
# <PIL.Image.Image image mode=RGB size=512x512>
# Image saved as generated_image.png

# %%
# !pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu118
from PIL import Image
import torch
from diffusers import StableDiffusionPipeline, DPMSolverMultistepScheduler

# Assuming you want to use the 'runwayml/stable-diffusion-v1-5' model
model_id = "stabilityai/stable-diffusion-2-1"
pipe = StableDiffusionPipeline.from_pretrained(model_id, torch_dtype=torch.float16) # Removed the extra indent
pipe = pipe.to("cuda")
pipe.scheduler = DPMSolverMultistepScheduler.from_config(pipe.scheduler.config)
device = "cuda" if torch.cuda.is_available() else "cpu"

def generate_image(prompt, image_size=(512, 512)):
    # Generate an image from the text prompt
    with torch.autocast(device):
        image = pipe(prompt)["images"][0]  # Corrected indentation
    return image

def save_image(image, filename="generated_image.png"):
    # Save the image to disk
    image.save(filename)
    print(f"Image saved as {filename}")

def show_image(image):
    # Display the image
    display(image)  # Use display for showing images in Colab
# Out:
# Looking in indexes: https://download.pytorch.org/whl/cu118
# ...
# Loading pipeline components...:   0%|          | 0/6 [00:00<?, ?it/s]

# %%
def main():
  # Get text prompt from user
  prompt = input("Enter your text prompt: ")
  # Generate image based on prompt
  generated_image = generate_image(prompt)
  # Save and show the image
  show_image(generated_image)
  save_image(generated_image)

if __name__ == "__main__":
  main()
# Out:
# Enter your text prompt: lion
#   0%|          | 0/50 [00:00<?, ?it/s]
# <PIL.Image.Image image mode=RGB size=768x768>
# Image saved as generated_image.png
